# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import random
sns.set_style("ticks")

# %config InlineBackend.figure_format = 'retina'

# %%
p_high = 0.0266
p_med = 0.0531
p_low = 0.0797
pal = ['#b2e1a8', '#b3cde3', '#fbb4ae']
pal2 = ['#abdea0', '#8fb6d6', '#f9867b']

# %%
def df_gen_lim_fail_35(a, skill_start, p_high, p_med, p_low):
    l = []
    l.append(a)
    tot_fail = 0
    skill = ''

    for i in range(9):
        idx = 0
        r = random.uniform(0, 1)

        if tot_fail < 2:
            while idx in range(3):
                if idx == 0:
                    x = (l[i][0] * (1 - p_high) /
                         (1 - (l[i][0] * p_high + l[i][1] * p_med +
                               l[i][2] * p_low)) * (1 - l[i][3]) +
                         l[i][0] * p_high /
                         (l[i][0] * p_high + l[i][1] * p_med + l[i][2] * p_low)
                         * l[i][3])
                    idx += 1
                elif idx == 1:
                    y = (l[i][1] * (1 - p_med) /
                         (1 - (l[i][0] * p_high + l[i][1] * p_med +
                               l[i][2] * p_low)) * (1 - l[i][3]) +
                         l[i][1] * p_med /
                         (l[i][0] * p_high + l[i][1] * p_med + l[i][2] * p_low)
                         * l[i][3])
                    idx += 1
                elif idx == 2:
                    z = (l[i][2] * (1 - p_low) /
                         (1 - (l[i][0] * p_high + l[i][1] * p_med +
                               l[i][2] * p_low)) * (1 - l[i][3]) +
                         l[i][2] * p_low /
                         (l[i][0] * p_high + l[i][1] * p_med + l[i][2] * p_low)
                         * l[i][3])
                    idx += 1

        if x > max(y, z):
            skill = 'H'
        elif y > max(x, z):
            skill = 'M'
        elif z > max(x, y):
            skill = 'L'

        if skill_start == 'H':
            if (i == 8):
                if r < p_high:
                    tot_fail += 1
                    l.append([x, y, z, 1, r, int(x + y + z), tot_fail, skill])
                else:
                    l.append([x, y, z, 0, r, int(x + y + z), tot_fail, skill])
            else:
                if r < p_high:
                    tot_fail += 1
                    l.append([x, y, z, 1, r, int(x + y + z), tot_fail, ''])
                else:
                    l.append([x, y, z, 0, r, int(x + y + z), tot_fail, ''])

        if skill_start == 'M':
            if (i == 8):
                if r < p_med:
                    tot_fail += 1
                    l.append([x, y, z, 1, r, int(x + y + z), tot_fail, skill])
                else:
                    l.append([x, y, z, 0, r, int(x + y + z), tot_fail, skill])
            else:
                if r < p_med:
                    tot_fail += 1
                    l.append([x, y, z, 1, r, int(x + y + z), tot_fail, ''])
                else:
                    l.append([x, y, z, 0, r, int(x + y + z), tot_fail, ''])

        if skill_start == 'L':
            if (i == 8):
                if r < p_low:
                    tot_fail += 1
                    l.append([x, y, z, 1, r, int(x + y + z), tot_fail, skill])
                else:
                    l.append([x, y, z, 0, r, int(x + y + z), tot_fail, skill])
            else:
                if r < p_low:
                    tot_fail += 1
                    l.append([x, y, z, 1, r, int(x + y + z), tot_fail, ''])
                else:
                    l.append([x, y, z, 0, r, int(x + y + z), tot_fail, ''])
    return l

def df_gen_lim_fail_45(a, skill_start, p_high, p_med, p_low):
    l = []
    l.append(a)
    tot_fail = 0
    skill = ''

    for i in range(19):
        idx = 0
        r = random.uniform(0, 1)

        if tot_fail < 2:
            while idx in range(3):
                if idx == 0:
                    x = (l[i][0] * (1 - p_high) /
                         (1 - (l[i][0] * p_high + l[i][1] * p_med +
                               l[i][2] * p_low)) * (1 - l[i][3]) +
                         l[i][0] * p_high /
                         (l[i][0] * p_high + l[i][1] * p_med + l[i][2] * p_low)
                         * l[i][3])
                    idx += 1
                elif idx == 1:
                    y = (l[i][1] * (1 - p_med) /
                         (1 - (l[i][0] * p_high + l[i][1] * p_med +
                               l[i][2] * p_low)) * (1 - l[i][3]) +
                         l[i][1] * p_med /
                         (l[i][0] * p_high + l[i][1] * p_med + l[i][2] * p_low)
                         * l[i][3])
                    idx += 1
                elif idx == 2:
                    z = (l[i][2] * (1 - p_low) /
                         (1 - (l[i][0] * p_high + l[i][1] * p_med +
                               l[i][2] * p_low)) * (1 - l[i][3]) +
                         l[i][2] * p_low /
                         (l[i][0] * p_high + l[i][1] * p_med + l[i][2] * p_low)
                         * l[i][3])
                    idx += 1

        if x > max(y, z):
            skill = 'H'
        elif y > max(x, z):
            skill = 'M'
        elif z > max(x, y):
            skill = 'L'

        if skill_start == 'H':
            if (i == 18):
                if r < p_high:
                    tot_fail += 1
                    l.append([x, y, z, 1, r, int(x + y + z), tot_fail, skill])
                else:
                    l.append([x, y, z, 0, r, int(x + y + z), tot_fail, skill])
            else:
                if r < p_high:
                    tot_fail += 1
                    l.append([x, y, z, 1, r, int(x + y + z), tot_fail, ''])
                else:
                    l.append([x, y, z, 0, r, int(x + y + z), tot_fail, ''])

        if skill_start == 'M':
            if (i == 18):
                if r < p_med:
                    tot_fail += 1
                    l.append([x, y, z, 1, r, int(x + y + z), tot_fail, skill])
                else:
                    l.append([x, y, z, 0, r, int(x + y + z), tot_fail, skill])
            else:
                if r < p_med:
                    tot_fail += 1
                    l.append([x, y, z, 1, r, int(x + y + z), tot_fail, ''])
                else:
                    l.append([x, y, z, 0, r, int(x + y + z), tot_fail, ''])

        if skill_start == 'L':
            if (i == 18):
                if r < p_low:
                    tot_fail += 1
                    l.append([x, y, z, 1, r, int(x + y + z), tot_fail, skill])
                else:
                    l.append([x, y, z, 0, r, int(x + y + z), tot_fail, skill])
            else:
                if r < p_low:
                    tot_fail += 1
                    l.append([x, y, z, 1, r, int(x + y + z), tot_fail, ''])
                else:
                    l.append([x, y, z, 0, r, int(x + y + z), tot_fail, ''])
    return l

def df_gen_lim_fail_55(a, skill_start, p_high, p_med, p_low):
    l = []
    l.append(a)
    tot_fail = 0
    skill = ''

    for i in range(29):
        idx = 0
        r = random.uniform(0, 1)

        if tot_fail < 2:
            while idx in range(3):
                if idx == 0:
                    x = (l[i][0] * (1 - p_high) /
                         (1 - (l[i][0] * p_high + l[i][1] * p_med +
                               l[i][2] * p_low)) * (1 - l[i][3]) +
                         l[i][0] * p_high /
                         (l[i][0] * p_high + l[i][1] * p_med + l[i][2] * p_low)
                         * l[i][3])
                    idx += 1
                elif idx == 1:
                    y = (l[i][1] * (1 - p_med) /
                         (1 - (l[i][0] * p_high + l[i][1] * p_med +
                               l[i][2] * p_low)) * (1 - l[i][3]) +
                         l[i][1] * p_med /
                         (l[i][0] * p_high + l[i][1] * p_med + l[i][2] * p_low)
                         * l[i][3])
                    idx += 1
                elif idx == 2:
                    z = (l[i][2] * (1 - p_low) /
                         (1 - (l[i][0] * p_high + l[i][1] * p_med +
                               l[i][2] * p_low)) * (1 - l[i][3]) +
                         l[i][2] * p_low /
                         (l[i][0] * p_high + l[i][1] * p_med + l[i][2] * p_low)
                         * l[i][3])
                    idx += 1

        if x > max(y, z):
            skill = 'H'
        elif y > max(x, z):
            skill = 'M'
        elif z > max(x, y):
            skill = 'L'

        if skill_start == 'H':
            if (i == 28):
                if r < p_high:
                    tot_fail += 1
                    l.append([x, y, z, 1, r, int(x + y + z), tot_fail, skill])
                else:
                    l.append([x, y, z, 0, r, int(x + y + z), tot_fail, skill])
            else:
                if r < p_high:
                    tot_fail += 1
                    l.append([x, y, z, 1, r, int(x + y + z), tot_fail, ''])
                else:
                    l.append([x, y, z, 0, r, int(x + y + z), tot_fail, ''])

        if skill_start == 'M':
            if (i == 28):
                if r < p_med:
                    tot_fail += 1
                    l.append([x, y, z, 1, r, int(x + y + z), tot_fail, skill])
                else:
                    l.append([x, y, z, 0, r, int(x + y + z), tot_fail, skill])
            else:
                if r < p_med:
                    tot_fail += 1
                    l.append([x, y, z, 1, r, int(x + y + z), tot_fail, ''])
                else:
                    l.append([x, y, z, 0, r, int(x + y + z), tot_fail, ''])

        if skill_start == 'L':
            if (i == 28):
                if r < p_low:
                    tot_fail += 1
                    l.append([x, y, z, 1, r, int(x + y + z), tot_fail, skill])
                else:
                    l.append([x, y, z, 0, r, int(x + y + z), tot_fail, skill])
            else:
                if r < p_low:
                    tot_fail += 1
                    l.append([x, y, z, 1, r, int(x + y + z), tot_fail, ''])
                else:
                    l.append([x, y, z, 0, r, int(x + y + z), tot_fail, ''])
    return l

def df_gen_lim_fail_65(a, skill_start, p_high, p_med, p_low):
    l = []
    l.append(a)
    tot_fail = 0
    skill = ''

    for i in range(39):
        idx = 0
        r = random.uniform(0, 1)

        if tot_fail < 2:
            while idx in range(3):
                if idx == 0:
                    x = (l[i][0] * (1 - p_high) /
                         (1 - (l[i][0] * p_high + l[i][1] * p_med +
                               l[i][2] * p_low)) * (1 - l[i][3]) +
                         l[i][0] * p_high /
                         (l[i][0] * p_high + l[i][1] * p_med + l[i][2] * p_low)
                         * l[i][3])
                    idx += 1
                elif idx == 1:
                    y = (l[i][1] * (1 - p_med) /
                         (1 - (l[i][0] * p_high + l[i][1] * p_med +
                               l[i][2] * p_low)) * (1 - l[i][3]) +
                         l[i][1] * p_med /
                         (l[i][0] * p_high + l[i][1] * p_med + l[i][2] * p_low)
                         * l[i][3])
                    idx += 1
                elif idx == 2:
                    z = (l[i][2] * (1 - p_low) /
                         (1 - (l[i][0] * p_high + l[i][1] * p_med +
                               l[i][2] * p_low)) * (1 - l[i][3]) +
                         l[i][2] * p_low /
                         (l[i][0] * p_high + l[i][1] * p_med + l[i][2] * p_low)
                         * l[i][3])
                    idx += 1

        if x > max(y, z):
            skill = 'H'
        elif y > max(x, z):
            skill = 'M'
        elif z > max(x, y):
            skill = 'L'

        if skill_start == 'H':
            if (i == 38):
                if r < p_high:
                    tot_fail += 1
                    l.append([x, y, z, 1, r, int(x + y + z), tot_fail, skill])
                else:
                    l.append([x, y, z, 0, r, int(x + y + z), tot_fail, skill])
            else:
                if r < p_high:
                    tot_fail += 1
                    l.append([x, y, z, 1, r, int(x + y + z), tot_fail, ''])
                else:
                    l.append([x, y, z, 0, r, int(x + y + z), tot_fail, ''])

        if skill_start == 'M':
            if (i == 38):
                if r < p_med:
                    tot_fail += 1
                    l.append([x, y, z, 1, r, int(x + y + z), tot_fail, skill])
                else:
                    l.append([x, y, z, 0, r, int(x + y + z), tot_fail, skill])
            else:
                if r < p_med:
                    tot_fail += 1
                    l.append([x, y, z, 1, r, int(x + y + z), tot_fail, ''])
                else:
                    l.append([x, y, z, 0, r, int(x + y + z), tot_fail, ''])

        if skill_start == 'L':
            if (i == 38):
                if r < p_low:
                    tot_fail += 1
                    l.append([x, y, z, 1, r, int(x + y + z), tot_fail, skill])
                else:
                    l.append([x, y, z, 0, r, int(x + y + z), tot_fail, skill])
            else:
                if r < p_low:
                    tot_fail += 1
                    l.append([x, y, z, 1, r, int(x + y + z), tot_fail, ''])
                else:
                    l.append([x, y, z, 0, r, int(x + y + z), tot_fail, ''])
    return l

# %%
cols = [
    'p_high', 'p_med', 'p_low', 'failure', 'rand_num', 'row_sum',
    'total_failures', 'perceived_skill'
]
ind = range(1, 41)

# %%
df_h_lim_fail_35 = {}
df_m_lim_fail_35 = {}
df_l_lim_fail_35 = {}
df_h_lim_fail_45 = {}
df_m_lim_fail_45 = {}
df_l_lim_fail_45 = {}
df_h_lim_fail_55 = {}
df_m_lim_fail_55 = {}
df_l_lim_fail_55 = {}
df_h_lim_fail_65 = {}
df_m_lim_fail_65 = {}
df_l_lim_fail_65 = {}

for i in range(1, 100001):
    df_h_lim_fail_35[i] = pd.DataFrame(df_gen_lim_fail_35(
        [1/3, 1/3, 1/3, 0, 0, 1, 0, ''], 'H', p_high, p_med, p_low),
                               columns=cols,
                               index=range(1, 11))
    df_m_lim_fail_35[i] = pd.DataFrame(df_gen_lim_fail_35(
        [1/3, 1/3, 1/3, 0, 0, 1, 0, ''], 'M', p_high, p_med, p_low),
                               columns=cols,
                               index=range(1, 11))
    df_l_lim_fail_35[i] = pd.DataFrame(df_gen_lim_fail_35(
        [1/3, 1/3, 1/3, 0, 0, 1, 0, ''], 'L', p_high, p_med, p_low),
                               columns=cols,
                               index=range(1, 11))
    df_h_lim_fail_45[i] = pd.DataFrame(df_gen_lim_fail_45(
        [1/3, 1/3, 1/3, 0, 0, 1, 0, ''], 'H', p_high, p_med, p_low),
                               columns=cols,
                               index=range(1, 21))
    df_m_lim_fail_45[i] = pd.DataFrame(df_gen_lim_fail_45(
        [1/3, 1/3, 1/3, 0, 0, 1, 0, ''], 'M', p_high, p_med, p_low),
                               columns=cols,
                               index=range(1, 21))
    df_l_lim_fail_45[i] = pd.DataFrame(df_gen_lim_fail_45(
        [1/3, 1/3, 1/3, 0, 0, 1, 0, ''], 'L', p_high, p_med, p_low),
                               columns=cols,
                               index=range(1, 21))
    df_h_lim_fail_55[i] = pd.DataFrame(df_gen_lim_fail_55(
        [1/3, 1/3, 1/3, 0, 0, 1, 0, ''], 'H', p_high, p_med, p_low),
                               columns=cols,
                               index=range(1, 31))
    df_m_lim_fail_55[i] = pd.DataFrame(df_gen_lim_fail_55(
        [1/3, 1/3, 1/3, 0, 0, 1, 0, ''], 'M', p_high, p_med, p_low),
                               columns=cols,
                               index=range(1, 31))
    df_l_lim_fail_55[i] = pd.DataFrame(df_gen_lim_fail_55(
        [1/3, 1/3, 1/3, 0, 0, 1, 0, ''], 'L', p_high, p_med, p_low),
                               columns=cols,
                               index=range(1, 31))
    df_h_lim_fail_65[i] = pd.DataFrame(df_gen_lim_fail_65(
        [1/3, 1/3, 1/3, 0, 0, 1, 0, ''], 'H', p_high, p_med, p_low),
                               columns=cols,
                               index=range(1, 41))
    df_m_lim_fail_65[i] = pd.DataFrame(df_gen_lim_fail_65(
        [1/3, 1/3, 1/3, 0, 0, 1, 0, ''], 'M', p_high, p_med, p_low),
                               columns=cols,
                               index=range(1, 41))
    df_l_lim_fail_65[i] = pd.DataFrame(df_gen_lim_fail_65(
        [1/3, 1/3, 1/3, 0, 0, 1, 0, ''], 'L', p_high, p_med, p_low),
                               columns=cols,
                               index=range(1, 41))

# %%
df_h_35_tot_H = 0
for i in range(1, len(df_h_lim_fail_35) + 1):
    if df_h_lim_fail_35[i].loc[10]['perceived_skill'] == 'H':
        df_h_35_tot_H += 1
print("df_h_35_tot_H:", df_h_35_tot_H)

df_h_35_tot_M = 0
for i in range(1, len(df_h_lim_fail_35) + 1):
    if df_h_lim_fail_35[i].loc[10]['perceived_skill'] == 'M':
        df_h_35_tot_M += 1
print("df_h_35_tot_M:", df_h_35_tot_M)

df_h_35_tot_L = 0
for i in range(1, len(df_h_lim_fail_35) + 1):
    if df_h_lim_fail_35[i].loc[10]['perceived_skill'] == 'L':
        df_h_35_tot_L += 1
print("df_h_35_tot_L:", df_h_35_tot_L)

df_m_35_tot_H = 0
for i in range(1, len(df_m_lim_fail_35) + 1):
    if df_m_lim_fail_35[i].loc[10]['perceived_skill'] == 'H':
        df_m_35_tot_H += 1
print("df_m_35_tot_H:", df_m_35_tot_H)

df_m_35_tot_M = 0
for i in range(1, len(df_m_lim_fail_35) + 1):
    if df_m_lim_fail_35[i].loc[10]['perceived_skill'] == 'M':
        df_m_35_tot_M += 1
print("df_m_35_tot_M:", df_m_35_tot_M)

df_m_35_tot_L = 0
for i in range(1, len(df_m_lim_fail_35) + 1):
    if df_m_lim_fail_35[i].loc[10]['perceived_skill'] == 'L':
        df_m_35_tot_L += 1
print("df_m_35_tot_L:", df_m_35_tot_L)

df_l_35_tot_H = 0
for i in range(1, len(df_l_lim_fail_35) + 1):
    if df_l_lim_fail_35[i].loc[10]['perceived_skill'] == 'H':
        df_l_35_tot_H += 1
print("df_l_35_tot_H:", df_l_35_tot_H)

df_l_35_tot_M = 0
for i in range(1, len(df_l_lim_fail_35) + 1):
    if df_l_lim_fail_35[i].loc[10]['perceived_skill'] == 'M':
        df_l_35_tot_M += 1
print("df_l_35_tot_M:", df_l_35_tot_M)

df_l_35_tot_L = 0
for i in range(1, len(df_l_lim_fail_35) + 1):
    if df_l_lim_fail_35[i].loc[10]['perceived_skill'] == 'L':
        df_l_35_tot_L += 1
print("df_l_35_tot_L:", df_l_35_tot_L)

df_h_35_tot_d = {
    "High Skill": df_h_35_tot_H,
    "Medium Skill": df_h_35_tot_M,
    "Low Skill": df_h_35_tot_L
}

df_m_35_tot_d = {
    "High Skill": df_m_35_tot_H,
    "Medium Skill": df_m_35_tot_M,
    "Low Skill": df_m_35_tot_L
}

df_l_35_tot_d = {
    "High Skill": df_l_35_tot_H,
    "Medium Skill": df_l_35_tot_M,
    "Low Skill": df_l_35_tot_L
}
# Out:
# df_h_35_tot_H: 80564
# df_h_35_tot_M: 0
# df_h_35_tot_L: 19436
# df_m_35_tot_H: 64669
# df_m_35_tot_M: 0
# df_m_35_tot_L: 35331
# df_l_35_tot_H: 51569
# df_l_35_tot_M: 0
# df_l_35_tot_L: 48431

# %%
df_h_45_tot_H = 0
for i in range(1, len(df_h_lim_fail_45) + 1):
    if df_h_lim_fail_45[i].loc[20]['perceived_skill'] == 'H':
        df_h_45_tot_H += 1
print("df_h_45_tot_H:", df_h_45_tot_H)

df_h_45_tot_M = 0
for i in range(1, len(df_h_lim_fail_45) + 1):
    if df_h_lim_fail_45[i].loc[20]['perceived_skill'] == 'M':
        df_h_45_tot_M += 1
print("df_h_45_tot_M:", df_h_45_tot_M)

df_h_45_tot_L = 0
for i in range(1, len(df_h_lim_fail_45) + 1):
    if df_h_lim_fail_45[i].loc[20]['perceived_skill'] == 'L':
        df_h_45_tot_L += 1
print("df_h_45_tot_L:", df_h_45_tot_L)

df_m_45_tot_H = 0
for i in range(1, len(df_m_lim_fail_45) + 1):
    if df_m_lim_fail_45[i].loc[20]['perceived_skill'] == 'H':
        df_m_45_tot_H += 1
print("df_m_45_tot_H:", df_m_45_tot_H)

df_m_45_tot_M = 0
for i in range(1, len(df_m_lim_fail_45) + 1):
    if df_m_lim_fail_45[i].loc[20]['perceived_skill'] == 'M':
        df_m_45_tot_M += 1
print("df_m_45_tot_M:", df_m_45_tot_M)

df_m_45_tot_L = 0
for i in range(1, len(df_m_lim_fail_45) + 1):
    if df_m_lim_fail_45[i].loc[20]['perceived_skill'] == 'L':
        df_m_45_tot_L += 1
print("df_m_45_tot_L:", df_m_45_tot_L)

df_l_45_tot_H = 0
for i in range(1, len(df_l_lim_fail_45) + 1):
    if df_l_lim_fail_45[i].loc[20]['perceived_skill'] == 'H':
        df_l_45_tot_H += 1
print("df_l_45_tot_H:", df_l_45_tot_H)

df_l_45_tot_M = 0
for i in range(1, len(df_l_lim_fail_45) + 1):
    if df_l_lim_fail_45[i].loc[20]['perceived_skill'] == 'M':
        df_l_45_tot_M += 1
print("df_l_45_tot_M:", df_l_45_tot_M)

df_l_45_tot_L = 0
for i in range(1, len(df_l_lim_fail_45) + 1):
    if df_l_lim_fail_45[i].loc[20]['perceived_skill'] == 'L':
        df_l_45_tot_L += 1
print("df_l_45_tot_L:", df_l_45_tot_L)

df_h_45_tot_d = {
    "High Skill": df_h_45_tot_H,
    "Medium Skill": df_h_45_tot_M,
    "Low Skill": df_h_45_tot_L
}

df_m_45_tot_d = {
    "High Skill": df_m_45_tot_H,
    "Medium Skill": df_m_45_tot_M,
    "Low Skill": df_m_45_tot_L
}

df_l_45_tot_d = {
    "High Skill": df_l_45_tot_H,
    "Medium Skill": df_l_45_tot_M,
    "Low Skill": df_l_45_tot_L
}
# Out:
# df_h_45_tot_H: 61397
# df_h_45_tot_M: 32741
# df_h_45_tot_L: 5862
# df_m_45_tot_H: 37450
# df_m_45_tot_M: 43860
# df_m_45_tot_L: 18690
# df_l_45_tot_H: 22705
# df_l_45_tot_M: 43714
# df_l_45_tot_L: 33581

# %%
df_h_55_tot_H = 0
for i in range(1, len(df_h_lim_fail_55) + 1):
    if df_h_lim_fail_55[i].loc[30]['perceived_skill'] == 'H':
        df_h_55_tot_H += 1
print("df_h_55_tot_H:", df_h_55_tot_H)

df_h_55_tot_M = 0
for i in range(1, len(df_h_lim_fail_55) + 1):
    if df_h_lim_fail_55[i].loc[30]['perceived_skill'] == 'M':
        df_h_55_tot_M += 1
print("df_h_55_tot_M:", df_h_55_tot_M)

df_h_55_tot_L = 0
for i in range(1, len(df_h_lim_fail_55) + 1):
    if df_h_lim_fail_55[i].loc[30]['perceived_skill'] == 'L':
        df_h_55_tot_L += 1
print("df_h_55_tot_L:", df_h_55_tot_L)

df_m_55_tot_H = 0
for i in range(1, len(df_m_lim_fail_55) + 1):
    if df_m_lim_fail_55[i].loc[30]['perceived_skill'] == 'H':
        df_m_55_tot_H += 1
print("df_m_55_tot_H:", df_m_55_tot_H)

df_m_55_tot_M = 0
for i in range(1, len(df_m_lim_fail_55) + 1):
    if df_m_lim_fail_55[i].loc[30]['perceived_skill'] == 'M':
        df_m_55_tot_M += 1
print("df_m_55_tot_M:", df_m_55_tot_M)

df_m_55_tot_L = 0
for i in range(1, len(df_m_lim_fail_55) + 1):
    if df_m_lim_fail_55[i].loc[30]['perceived_skill'] == 'L':
        df_m_55_tot_L += 1
print("df_m_55_tot_L:", df_m_55_tot_L)

df_l_55_tot_H = 0
for i in range(1, len(df_l_lim_fail_55) + 1):
    if df_l_lim_fail_55[i].loc[30]['perceived_skill'] == 'H':
        df_l_55_tot_H += 1
print("df_l_55_tot_H:", df_l_55_tot_H)

df_l_55_tot_M = 0
for i in range(1, len(df_l_lim_fail_55) + 1):
    if df_l_lim_fail_55[i].loc[30]['perceived_skill'] == 'M':
        df_l_55_tot_M += 1
print("df_l_55_tot_M:", df_l_55_tot_M)

df_l_55_tot_L = 0
for i in range(1, len(df_l_lim_fail_55) + 1):
    if df_l_lim_fail_55[i].loc[30]['perceived_skill'] == 'L':
        df_l_55_tot_L += 1
print("df_l_55_tot_L:", df_l_55_tot_L)

df_h_55_tot_d = {
    "High Skill": df_h_55_tot_H,
    "Medium Skill": df_h_55_tot_M,
    "Low Skill": df_h_55_tot_L
}

df_m_55_tot_d = {
    "High Skill": df_m_55_tot_H,
    "Medium Skill": df_m_55_tot_M,
    "Low Skill": df_m_55_tot_L
}

df_l_55_tot_d = {
    "High Skill": df_l_55_tot_H,
    "Medium Skill": df_l_55_tot_M,
    "Low Skill": df_l_55_tot_L
}
# Out:
# df_h_55_tot_H: 84739
# df_h_55_tot_M: 9299
# df_h_55_tot_L: 5962
# df_m_55_tot_H: 59397
# df_m_55_tot_M: 21876
# df_m_55_tot_L: 18727
# df_l_55_tot_H: 37743
# df_l_55_tot_M: 28602
# df_l_55_tot_L: 33655

# %%
df_h_65_tot_H = 0
for i in range(1, len(df_h_lim_fail_65) + 1):
    if df_h_lim_fail_65[i].loc[40]['perceived_skill'] == 'H':
        df_h_65_tot_H += 1
print("df_h_65_tot_H:", df_h_65_tot_H)

df_h_65_tot_M = 0
for i in range(1, len(df_h_lim_fail_65) + 1):
    if df_h_lim_fail_65[i].loc[40]['perceived_skill'] == 'M':
        df_h_65_tot_M += 1
print("df_h_65_tot_M:", df_h_65_tot_M)

df_h_65_tot_L = 0
for i in range(1, len(df_h_lim_fail_65) + 1):
    if df_h_lim_fail_65[i].loc[40]['perceived_skill'] == 'L':
        df_h_65_tot_L += 1
print("df_h_65_tot_L:", df_h_65_tot_L)

df_m_65_tot_H = 0
for i in range(1, len(df_m_lim_fail_65) + 1):
    if df_m_lim_fail_65[i].loc[40]['perceived_skill'] == 'H':
        df_m_65_tot_H += 1
print("df_m_65_tot_H:", df_m_65_tot_H)

df_m_65_tot_M = 0
for i in range(1, len(df_m_lim_fail_65) + 1):
    if df_m_lim_fail_65[i].loc[40]['perceived_skill'] == 'M':
        df_m_65_tot_M += 1
print("df_m_65_tot_M:", df_m_65_tot_M)

df_m_65_tot_L = 0
for i in range(1, len(df_m_lim_fail_65) + 1):
    if df_m_lim_fail_65[i].loc[40]['perceived_skill'] == 'L':
        df_m_65_tot_L += 1
print("df_m_65_tot_L:", df_m_65_tot_L)

df_l_65_tot_H = 0
for i in range(1, len(df_l_lim_fail_65) + 1):
    if df_l_lim_fail_65[i].loc[40]['perceived_skill'] == 'H':
        df_l_65_tot_H += 1
print("df_l_65_tot_H:", df_l_65_tot_H)

df_l_65_tot_M = 0
for i in range(1, len(df_l_lim_fail_65) + 1):
    if df_l_lim_fail_65[i].loc[40]['perceived_skill'] == 'M':
        df_l_65_tot_M += 1
print("df_l_65_tot_M:", df_l_65_tot_M)

df_l_65_tot_L = 0
for i in range(1, len(df_l_lim_fail_65) + 1):
    if df_l_lim_fail_65[i].loc[40]['perceived_skill'] == 'L':
        df_l_65_tot_L += 1
print("df_l_65_tot_L:", df_l_65_tot_L)

df_h_65_tot_d = {
    "High Skill": df_h_65_tot_H,
    "Medium Skill": df_h_65_tot_M,
    "Low Skill": df_h_65_tot_L
}

df_m_65_tot_d = {
    "High Skill": df_m_65_tot_H,
    "Medium Skill": df_m_65_tot_M,
    "Low Skill": df_m_65_tot_L
}

df_l_65_tot_d = {
    "High Skill": df_l_65_tot_H,
    "Medium Skill": df_l_65_tot_M,
    "Low Skill": df_l_65_tot_L
}
# Out:
# df_h_65_tot_H: 85156
# df_h_65_tot_M: 9028
# df_h_65_tot_L: 5816
# df_m_65_tot_H: 59416
# df_m_65_tot_M: 21667
# df_m_65_tot_L: 18917
# df_l_65_tot_H: 37338
# df_l_65_tot_M: 28797
# df_l_65_tot_L: 33865

# %%
f, axes = plt.subplots(4, 3, figsize=(10, 10), sharey=True)

sns.barplot(x=list(df_h_35_tot_d.keys()),
            y=list(df_h_35_tot_d.values()),
            ax=axes[0, 0],
            palette=pal,
            edgecolor='k')
sns.barplot(x=list(df_m_35_tot_d.keys()),
            y=list(df_m_35_tot_d.values()),
            ax=axes[0, 1],
            palette=pal,
            edgecolor='k')
sns.barplot(x=list(df_l_35_tot_d.values()),
            y=list(df_l_35_tot_d.values()),
            ax=axes[0, 2],
            palette=pal,
            edgecolor='k')
sns.barplot(x=list(df_h_45_tot_d.keys()),
            y=list(df_h_45_tot_d.values()),
            ax=axes[1, 0],
            palette=pal,
            edgecolor='k')
sns.barplot(x=list(df_m_45_tot_d.keys()),
            y=list(df_m_45_tot_d.values()),
            ax=axes[1, 1],
            palette=pal,
            edgecolor='k')
sns.barplot(x=list(df_l_45_tot_d.values()),
            y=list(df_l_45_tot_d.values()),
            ax=axes[1, 2],
            palette=pal,
            edgecolor='k')
sns.barplot(x=list(df_h_55_tot_d.keys()),
            y=list(df_h_55_tot_d.values()),
            ax=axes[2, 0],
            palette=pal,
            edgecolor='k')
sns.barplot(x=list(df_m_55_tot_d.keys()),
            y=list(df_m_55_tot_d.values()),
            ax=axes[2, 1],
            palette=pal,
            edgecolor='k')
sns.barplot(x=list(df_l_55_tot_d.values()),
            y=list(df_l_55_tot_d.values()),
            ax=axes[2, 2],
            palette=pal,
            edgecolor='k')
sns.barplot(x=list(df_h_65_tot_d.keys()),
            y=list(df_h_65_tot_d.values()),
            ax=axes[3, 0],
            palette=pal,
            edgecolor='k')
sns.barplot(x=list(df_m_65_tot_d.keys()),
            y=list(df_m_65_tot_d.values()),
            ax=axes[3, 1],
            palette=pal,
            edgecolor='k')
sns.barplot(x=list(df_l_65_tot_d.values()),
            y=list(df_l_65_tot_d.values()),
            ax=axes[3, 2],
            palette=pal,
            edgecolor='k')

for i in range(4):
    for j in range(3):
        for p in axes[i, j].patches:
            axes[i,j].annotate('{:.1%}'.format(int(p.get_height())/100000),
                             (p.get_x() + p.get_width() / 2., p.get_height()),
                             ha='center',
                             va='center',
                             xytext=(0, 5),
                             textcoords='offset points',
                             weight='bold')

# for i in range(4):
#     for j in range(3):
#         for p in axes[i, j].patches:
#             axes[i,j].annotate(format(int(p.get_height()), 'd'),
#                              (p.get_x() + p.get_width() / 2., p.get_height()),
#                              ha='center',
#                              va='center',
#                              xytext=(0, 5),
#                              textcoords='offset points',
#                              weight='bold')

plt.xticks(range(3), list(df_l_65_tot_d.keys()))
for ax in axes.flat:
    ax.label_outer()
    ax.set_ylim([0,95000])

axes[0, 0].set_title("High Skill 35 Year-Olds")
axes[0, 1].set_title("Medium Skill 35 Year-Olds")
axes[0, 2].set_title("Low Skill 35 Year-Olds")
axes[1, 0].set_title("High Skill 45 Year-Olds")
axes[1, 1].set_title("Medium Skill 45 Year-Olds")
axes[1, 2].set_title("Low Skill 45 Year-Olds")
axes[2, 0].set_title("High Skill 55 Year-Olds")
axes[2, 1].set_title("Medium Skill 55 Year-Olds")
axes[2, 2].set_title("Low Skill 55 Year-Olds")
axes[3, 0].set_title("High Skill 65 Year-Olds")
axes[3, 1].set_title("Medium Skill 65 Year-Olds")
axes[3, 2].set_title("Low Skill 65 Year-Olds")

f.suptitle('Perceived Skill Group Among 10 Year Intervals:')
plt.tight_layout()
plt.savefig('Perceived_Skill_Group_10_Year_Intervals', dpi=300)
